# %%
# !pip install ipykernel

# %%
# !python -m pip install "pymongo[srv]"
# !pip install openpyxl

# %%
import pandas as pd
import openpyxl
# colnames = ['Pk_id','DeviceId','UserMobileNo','id','MobAddress','sender	body','SMSdate','dateSent','kind','SMSread','CrtdDt','CrtdBy']
# df = pd.read_csv("SMS Data.csv", names = colnames, index_col = None)
colnames = ['Source','Sender ID','SMS_Details']
df = pd.read_excel("SMS Data.xlsx", names = colnames, index_col = None)

# from pymongo import MongoClient
import json
import pymongo
mongoClient = pymongo.MongoClient("mongodb+srv://root:root@cluster0.xlt5dac.mongodb.net/?retryWrites=true&w=majority")
db = mongoClient['mysms_data']
sms = db['sms_msg']
print(mongoClient)

# df.reset_index(inplace=True)
# data_dict = df.to_dict("sentence")
db.sms.insert_many(df.to_dict('records'))
# Out:
# MongoClient(host=['ac-dxhxrlg-shard-00-01.xlt5dac.mongodb.net:27017', 'ac-dxhxrlg-shard-00-02.xlt5dac.mongodb.net:27017', 'ac-dxhxrlg-shard-00-00.xlt5dac.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-bsbr7o-shard-0', tls=True)

# %%
import pandas as pd
df = pd.read_csv("SMS Data.csv")
df
# Out:
#     Unnamed: 0  Pk_id          DeviceId  UserMobileNo     id  Mobaddress
# 0            0      1           ME12157    9182591745  15337  8838975819  \
# 1            1      2           ME12157    9182591745  15292  9717465555
# 2            2      3           ME12157    9182591745  15217  9717465555
# 3            3      4           ME12157    9182591745  13522   VM-AxisBk
# 4            4      5  asdfwe2342rqwerq    9182591745  15337  8838975819
# 5            5      6  asdfwe2342rqwerq    9182591745  15292  9717465555
# 6            6      7  asdfwe2342rqwerq    9182591745  15217  9717465555
# 7            7      8  asdfwe2342rqwerq    9182591745  13522   VM-AxisBk
# 8            8      9  asdfwe2342rqwerq    9182591745  13522   VM-AxisBk
# 9            9     10  asdfwe2342rqwerq    9182591745  13522   VM-AxisBk
# 10          10     11  asdfwe2342rqwerq    9182591745  13522   VM-AxisBk
# 11          11     12  asdfwe2342rqwerq    9182591745  13522   VM-AxisBk
#
# ...

# %%
import pandas as pd
import re

def add_spaces_around_numbers(sentence):
    return re.sub(r'(\d+(?:\.\d{1,2})?)', r' \1 ', sentence)

def add_spaces_to_column(df, column_name):
    df[column_name] = df[column_name].astype(str).apply(lambda x: add_spaces_around_numbers(x) if not re.search(r'\d\s|\s\d', x) else x)
    return df

# Example usage:
df = pd.DataFrame({'text': ['I have 5 apples.', 'There are10.00cats.', 'The priceis$12.34as max retail price.']})

print("Before:")
print(df)

df = add_spaces_to_column(df, 'text')

print("\nAfter:")
print(df)
# Out:
# Before:
#                                     text
# 0                       I have 5 apples.
# 1                    There are10.00cats.
# 2  The priceis$12.34as max retail price.
#
# After:
#                                       text
# 0                         I have 5 apples.
# 1                    There are 10.00 cats.
# 2  The priceis$ 12.34 as max retail price.

# %%
import pandas as pd
df = pd.read_csv("V1.csv")
df['SMS_Details'] = add_spaces_to_column(df, 'SMS_Details')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19832\1378252165.py in ?()
# ----> 3 import pandas as pd
#       4 df = pd.read_csv("V1.csv")
#       5 df['SMS_Details'] = add_spaces_to_column(df, 'SMS_Details')
#
# d:\Projects\NER_with_custom_data\nerp\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    3946             self._setitem_frame(key, value)
#    3947         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    3948             self._setitem_array(key, value)
#    3949         elif isinstance(value, DataFrame):
# -> 3950             self._set_item_frame_value(key, value)
#    3951         elif (
#    3952             is_list_like(value)
#    3953             and not self.columns.is_unique
#
# d:\Projects\NER_with_custom_data\nerp\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
# ...

# %%
import pandas as pd
df = pd.read_csv("SMS Data.csv")
df

# %%
import json
import pandas as pd

def read_json_file(file_path):
    with open(file_path) as file:
        data = json.load(file)
    return data

annotations = read_json_file("annotations (1).json")
annotations = pd.DataFrame(annotations)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 10
#       7     return data
#       9 annotations = read_json_file("annotations (1).json")
# ---> 10 annotations = pd.DataFrame(annotations)
#
# File d:\Projects\NER_with_custom_data\nerp\lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# ...

# %%
import pandas as pd
import json

def read_json_file(file_path):
    with open(file_path) as file:
        data = json.load(file)

    # Determine the keys for all records
    unique_keys = set()
    for record in data:
        if isinstance(record, dict):
            unique_keys.update(record.keys())

    # Create a list of dictionaries with consistent keys
    processed_data = []
    for record in data:
        if isinstance(record, dict):
            processed_record = {}
            for key in unique_keys:
                processed_record[key] = record.get(key)
            processed_data.append(processed_record)

    # Create DataFrame from the preprocessed data
    df = pd.DataFrame(processed_data)
    return df


annotations = read_json_file("annotations (1).json")
print(annotations)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
df = pd.read_excel("SMS Data.xlsx")
df
# Out:
#                       Source  Sender ID
# 0                Indian Bank    BT-INBN  \
# 1                        NaN        NaN
# 2                        NaN        NaN
# 3                        NaN        NaN
# 4    State Bank of Mauritius   JD-SBMIN
# ..                       ...        ...
# 298                      NaN  BP-IOBCHN
# 299                      NaN        NaN
# 300                      NaN  VX-ICICIB
# 301                      NaN  VD-SMRTBY
# 302                      NaN  VD-HDFCBK
#
#                                            SMS_Details
# 0    Hi Vasanthapathi, https://usage.%27%2C/ 👋 With...
# 1    Hi customer, what is next on your list? Make i...
# 2    Rs.105 transferred from A/c ...5557 to:UPI/304...
# 3    Rs 60.00 debited from A/C XXXXXX5559 and credi...
# 4    Dear Customer, IDBI Bank offers Auto Loan at l...
# ..                                                 ...
# 298  Rs.3000.00 Credited to SB-xxx9488 AcBal:3484.6...
# ...
