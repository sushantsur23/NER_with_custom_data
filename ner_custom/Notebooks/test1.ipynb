# %% [markdown]
# Insertion of data into mongo db

# %%
# !python -m pip install "pymongo[srv]"
# Out:
# Requirement already satisfied: pymongo[srv] in d:\projects\ner_with_custom_data\nerp\lib\site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in d:\projects\ner_with_custom_data\nerp\lib\site-packages (from pymongo[srv]) (2.3.0)

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in d:\projects\ner_with_custom_data\nerp\lib\site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in d:\projects\ner_with_custom_data\nerp\lib\site-packages (from pymongo[srv]) (2.3.0)

# %%
import pandas as pd
import openpyxl
colnames = ['sentence']
df = pd.read_excel('rawsmsdata.xlsx',names = colnames, index_col = None)
df
# Out:
#                                              sentence
# 0   AccountNo XXXXXX3406 CREDIT with amount Rs.110...
# 1   Rs.17.70 Debited to SB-xxx9488 AcBal 489.60 CL...
# 2   UPDATE INR:32,241.00 debited from HDFC Bank XX...
# 3   Debited INR.500.00 from A/c X2731 on 08-MAR-20...
# 4   INR.500.00 withdrawn via card 6530 on 08/03/23...
# 5   ICICI Bank Acc XX424 debited with INR 500.00 o...
# 6   Rs.500.00 withdrawn at ATM ID:IOBD5123 SRIRAM ...
# 7   INR 500.00 debited from A/c XXXXXXXX3885 towar...
# 8   Dear Customer statement for YES BANK Credit Ca...
# 9   INR 179.00 spent on ICICI Bank Card XX1008 on ...
# 10  Alert!You've spent Rs.272 On HDFC Bank CREDIT ...
# 11  Thanks for using HDFC Bank Visa Foodplus Card ...
# 12  You've spent Rs.129 On HDFC Bank CREDIT Card x...
# 13  You've spent Rs.2514 On HDFC Bank CREDIT Card ...
# 14  You've spent Rs.274 On HDFC Bank CREDIT Card x...
# 15  INR 230.00 spent on ICICI Bank Card XX1008 on ...
# 16  Rs.3000.00 Credited to SB-xxx9488 AcBal:3484.6...
# 17  Received! Your request for CashBack of Rs. 500...
# 18  Your payment of INR 93,308.66 towards your YES...
# 19  INR 804.00 spent on ICICI Bank Card XX1008 on ...
# 20  INR 364.00 spent on ICICI Bank Card XX1008 on ...
# 21  Refund of ₹186.47 for your Zomato order from F...
# 22  HDFC Bank: Rs 4400.00 debited from a/c **8448 ...
# 23  DEAR HDFCBANK CARDMEMBER, PAYMENT OF Rs. 40000...
# 24  Debited INR 99.00 from A/c X2731 on 15-MAR-202...
# 25  Your VPA 8095424559@paytm linked to Indian Ban...
# 26  INR 179.00 spent on ICICI Bank Card XX1008 on ...
# 27  You've hand-picked groceries for Rs. 262.00 at...
# 28  You've spent Rs.295 On HDFC Bank CREDIT Card x...

# %%
df
# Out:
#                                              sentence
# 0   AccountNo XXXXXX3406 CREDIT with amount Rs.110...
# 1   Rs.17.70 Debited to SB-xxx9488 AcBal 489.60 CL...
# 2   UPDATE INR:32,241.00 debited from HDFC Bank XX...
# 3   Debited INR.500.00 from A/c X2731 on 08-MAR-20...
# 4   INR.500.00 withdrawn via card 6530 on 08/03/23...
# 5   ICICI Bank Acc XX424 debited with INR 500.00 o...
# 6   Rs.500.00 withdrawn at ATM ID:IOBD5123 SRIRAM ...
# 7   INR 500.00 debited from A/c XXXXXXXX3885 towar...
# 8   Dear Customer statement for YES BANK Credit Ca...
# 9   INR 179.00 spent on ICICI Bank Card XX1008 on ...
# 10  Alert!You've spent Rs.272 On HDFC Bank CREDIT ...
# 11  Thanks for using HDFC Bank Visa Foodplus Card ...
# 12  You've spent Rs.129 On HDFC Bank CREDIT Card x...
# 13  You've spent Rs.2514 On HDFC Bank CREDIT Card ...
# 14  You've spent Rs.274 On HDFC Bank CREDIT Card x...
# 15  INR 230.00 spent on ICICI Bank Card XX1008 on ...
# 16  Rs.3000.00 Credited to SB-xxx9488 AcBal:3484.6...
# 17  Received! Your request for CashBack of Rs. 500...
# 18  Your payment of INR 93,308.66 towards your YES...
# 19  INR 804.00 spent on ICICI Bank Card XX1008 on ...
# 20  INR 364.00 spent on ICICI Bank Card XX1008 on ...
# 21  Refund of ₹186.47 for your Zomato order from F...
# 22  HDFC Bank: Rs 4400.00 debited from a/c **8448 ...
# 23  DEAR HDFCBANK CARDMEMBER, PAYMENT OF Rs. 40000...
# 24  Debited INR 99.00 from A/c X2731 on 15-MAR-202...
# 25  Your VPA 8095424559@paytm linked to Indian Ban...
# 26  INR 179.00 spent on ICICI Bank Card XX1008 on ...
# 27  You've hand-picked groceries for Rs. 262.00 at...
# 28  You've spent Rs.295 On HDFC Bank CREDIT Card x...

# %%
df1 = df.to_json()
df1
# Out:
# '{"sentence":{"0":"AccountNo XXXXXX3406 CREDIT with amount Rs.110000.00 on 03-03-2023 Balance Rs.77396.00 [IN292004]","1":"Rs.17.70 Debited to SB-xxx9488 AcBal 489.60 CLRBal 489.60 [CHRGS- SMS] CHENNAI INDIRA NAGAR on 06-03-2023 04:07:40 IOB","2":"UPDATE INR:32,241.00 debited from HDFC Bank XX0219 on 07-MAR-23 Info: EMI 119094314 Chq S1190943140211 0323119094314 Avl bal INR.2,149.90","3":"Debited INR.500.00 from A\\/c X2731 on 08-MAR-2023 NDA-1094-S1CWI796 FIRST AVENUE INDIRA N CHENNAI TNIN Bal INR:1,895.00 Not you? Call 180012001200 & dial 1 AU Bank","4":"INR.500.00 withdrawn via card 6530 on 08\\/03\\/23 Avl Bal:INR 505.08 If not you SMS HOTLIST 6530 to 7065154444 For Non-DBS ATM usage fee go.dbs.com\\/ratesfees DBS BANK","5":"ICICI Bank Acc XX424 debited with INR 500.00 on 09-Mar-23 NFS*IOBD5123* Avb Bal: INR0.00 For dispute Call 18002662 or SMS BLOCK 424 to 9215676766","6":"Rs.500.00 withdrawn at ATM ID:IOBD5123 SRIRAM NAGAR CHENNAI \\u00a0CHENNAI on 09\\/03\\/23 14:03 from Ac:XXX550656. Bal:504.10 CR Always use INDIAN BANK ATM to avoid charges SMS BLOCK to +91-9289592895 to block all digital channel transactions if the current transaction is not done by you","7":"INR 500.00 debited from A\\/c XXXXXXXX3885 towards ATM WITHDRAWAL 472357******8272 SRIRAM NAGAR CHEN CHENNAI TNIN Value 09-MAR-2023 Avl Bal is INR2.57 For any query call 1800-103-1222 Equitas Bank","8":"Dear Customer statement for YES BANK Credit Card ending 3262 has been generated and will reach you shortly Total Due: INR 93308.66 Min Due:INR14627.76 and Payment Due Date: 04\\/04\\/23 Please pay including the decimal value to avoid charges immediate payment is required if previous statement dues are unpaid YES Bank Limited","9":"INR 179.00 spent on ICICI Bank Card XX1008 on 16-Mar-23 at AMAZON INDIA Avl Lmt: INR 6,07,940.00 To dispute call 18002662\\/SMS BLOCK 1008 to 9215676766","10":"Alert!You\'ve spent Rs.272 On HDFC Bank CREDIT Card xx9186 at SWIGGYIN3549783 In: BANGALORE Date: 2023-04-19:07:33:25.Not you? Call 18002586161","11":"Thanks for using HDFC Bank Visa Foodplus Card Card XXXX8938 for INR 343 at HITA LIFE VENTURES PRIV on 19-APR-23 07:04 PM. Card Bal: INR 1930.75. Not You ? Call 912261606161","12":"You\'ve spent Rs.129 On HDFC Bank CREDIT Card xx9186 At GFM RETAIL PRIVATE LIM On 2023-03-21:08:31:01 Avl bal: Rs.30323 Curr O\\/s: Rs.44677 Not you?Call 18002586161","13":"You\'ve spent Rs.2514 On HDFC Bank CREDIT Card xx9186 At AMAZON PAY INDIA Pvt Ltd On 2023-03-19:08:33:29 Avl bal: Rs.32285.05 Curr O\\/s: Rs.42714.95 Not you?Call 18002586161","14":"You\'ve spent Rs.274 On HDFC Bank CREDIT Card xx9186 At ZEPTO On 2023-03-31:06:55:22 Avl bal: Rs.20638 Curr O\\/s: Rs.54362 Not you?Call 18002586161","15":"INR 230.00 spent on ICICI Bank Card XX1008 on 30-Mar-23 at WWW SWIGGY. Avl Lmt: INR 3,06,230.00. To dispute,call 18002662\\/SMS BLOCK 1008 to 9215676766","16":"Rs.3000.00 Credited to SB-xxx9488 AcBal:3484.60 CLRBal: 3484.60 [DEPFAIL-19 ] CHENNAI-INDIRA NAGAR on 23-03-2023 18:17:59.IOB.","17":"Received! Your request for CashBack of Rs. 500.00 from the redemption of 3329 Reward Points on HDFC Bank Credit Card 9186. You\'ll receive it in 2 working days","18":"Your payment of INR 93,308.66 towards your YES Bank credit card XXXX-3262 has failed. Any amount, if debited from your account and received by CRED, will be refunded within 5 days. You can view more details for this order ID: D3G41124NPQD here: https:\\/\\/app.cred.club\\/spQx\\/3m739r1s","19":"INR 804.00 spent on ICICI Bank Card XX1008 on 08-Apr-23 at Amazon.in - Gro. Avl Lmt: INR 3,05,406.60. To dispute,call 18002662\\/SMS BLOCK 1008 to 9215676766","20":"INR 364.00 spent on ICICI Bank Card XX1008 on 08-Apr-23 at Amazon.in - Gro. Avl Lmt: INR 3,06,210.60. To dispute,call 18002662\\/SMS BLOCK 1008 to 9215676766","21":"Refund of \\u20b9186.47 for your Zomato order from French Loaf has been successfully processed and shall reflect in your account by now. To track your refund please click here: https:\\/\\ ...

# %%
# from pymongo import MongoClient
import json
import pymongo
mongoClient = pymongo.MongoClient("mongodb+srv://root:root@cluster0.xlt5dac.mongodb.net/?retryWrites=true&w=majority")
db = mongoClient['sms_data']
sms = db['sms']
print(mongoClient)

# df.reset_index(inplace=True)
# data_dict = df.to_dict("sentence")
db.sms.insert_many(df.to_dict('records'))


# docs = json.loads(df1)
# collection.insert_many(docs)

# collection.insert_many(df.to_dict())

# header = ['name', 'age', 'country']
# csvFile = open('rawssmsdata.csv', 'r')
# reader = csv.DictReader(csvFile)

# for each in reader:
#     row = {}
#     for field in header:
#         row[field] = each[field]
#     collection.insert(row)
# Out:
# MongoClient(host=['ac-dxhxrlg-shard-00-00.xlt5dac.mongodb.net:27017', 'ac-dxhxrlg-shard-00-01.xlt5dac.mongodb.net:27017', 'ac-dxhxrlg-shard-00-02.xlt5dac.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-bsbr7o-shard-0', tls=True)

# %%
file_path="/config/workspace/aps_failure_training_set1.csv"
from ner_custom.data_access.data import MongoData
from ner_custom.constant.training_pipeline import DATA_INGESTION_COLLECTION_NAME
from main import set_env_variable
import os
if __name__=='__main__':
    data_file_path="/config/workspace/aps_failure_training_set1.csv"
    env_file_path='/config/workspace/env.yaml'
    set_env_variable(env_file_path)
    print( os.environ['MONGO_DB_URL'])
    sd = MongoData()
    if DATA_INGESTION_COLLECTION_NAME in sd.mongo_client.database.list_collection_names():
        sd.mongo_client.database[DATA_INGESTION_COLLECTION_NAME].drop()
    sd.save_csv_file(file_path=data_file_path,collection_name=DATA_INGESTION_COLLECTION_NAME)
